# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
release_dates = pd.DataFrame.from_csv('data/release_dates.csv', index_col=None,
                                      parse_dates=['date'], infer_datetime_format=True)
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4                 #Horror  2015           UK 2016-05-16

# %% [markdown]
# ### Make a bar plot of the months in which movies with "Christmas" in their title tend to be released in the USA.

# %%
r = release_dates[(release_dates.title.str.contains('Christmas'))
                 & (release_dates.country == 'USA')]
r.groupby(r.date.dt.month).size().plot(kind='bar')

# %% [markdown]
# ### Make a bar plot of the months in which movies whose titles start with "The Hobbit" are released in the USA.

# %%
r = release_dates[(release_dates.title.str.startswith('The Hobbit'))
                 & (release_dates.country == 'USA')]
r.groupby(r.date.dt.month).size().plot(kind='bar')

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA.

# %%
r = release_dates[(release_dates.title.str.contains('Romance'))
                 & (release_dates.country == 'USA')]
r.groupby(r.date.dt.dayofweek).size().plot(kind='bar')

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Action" in their title tend to be released in the USA.

# %%
r = release_dates[(release_dates.title.str.contains('Action'))
                 & (release_dates.country == 'USA')]
r.groupby(r.date.dt.dayofweek).size().plot(kind='bar')

# %% [markdown]
# ### On which date was each Judi Dench movie from the 1990s released in the USA?

# %%
r = release_dates[(release_dates.country == 'USA')
                 & (release_dates.year // 10 == 199)]
s = r.merge(cast)
s = s[s.name == 'Judi Dench'].sort_values('date')
s.date
# Out:
# 43314    1995-11-17
# 54558    1996-03-22
# 45543    1996-12-25
# 73041    1997-10-03
# 124922   1997-12-19
# 92589    1999-01-08
# 102345   1999-05-14
# 122412   1999-11-19
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ### In which months do films with Judi Dench tend to be released in the USA?

# %%
r = release_dates[release_dates.country == 'USA']
s = r.merge(cast)
s = s[s.name == 'Judi Dench']
s.groupby(s.date.dt.month).size().plot(kind='bar')

# %% [markdown]
# ### In which months do films with Tom Cruise tend to be released in the USA?

# %%
r = release_dates[release_dates.country == 'USA']
s = r.merge(cast)
s = s[s.name == 'Tom Cruise']
s.groupby(s.date.dt.month).size().plot(kind='bar')

# %%
r = release_dates
r.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                 #Beings  2015      Romania 2015-01-29
# 2  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21
# 3                 #Horror  2015          USA 2015-11-20
# 4                 #Horror  2015           UK 2016-05-16

# %%
r.date.dt.dayofweek
# Out:
# 0         4
# 1         3
# 2         2
# 3         4
# 4         0
# 5         1
# 6         3
# 7         4
# 8         1
# 9         5
# 10        1
# 11        4
# 12        4
# 13        2
# 14        3
# 15        1
# 16        3
# 17        4
# 18        0
# 19        4
# 20        1
# 21        2
# 22        3
# 23        5
# 24        2
# 25        4
# 26        0
# 27        5
# 28        2
# 29        5
#          ..
# 460338    3
# 460339    3
# 460340    3
# 460341    3
# 460342    3
# 460343    3
# 460344    3
# 460345    3
# 460346    3
# 460347    3
# 460348    3
# 460349    3
# 460350    3
# 460351    4
# 460352    4
# 460353    4
# 460354    4
# 460355    4
# 460356    4
# 460357    4
# 460358    4
# 460359    4
# 460360    4
# 460361    4
# 460362    4
# 460363    4
# 460364    4
# 460365    4
# 460366    4
# 460367    4
# Name: date, dtype: int64

# %%
# merge

c = cast
c = c[c.name == 'Ellen Page']
c.merge(release_dates)
# Out:
#                      title  year        name     type      character     n  \
# 0        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 1        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 2        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 3        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 4        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 5        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 6        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 7        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 8        An American Crime  2007  Ellen Page  actress  Sylvia Likens   1.0
# 9               Flatliners  2017  Ellen Page  actress       Courtney   NaN
# 10              Flatliners  2017  Ellen Page  actress       Courtney   NaN
# ...

# %%
# pivot

r = release_dates
r = r[r.title.str.startswith('Star Wars: Episode')]
r = r[r.country.str.startswith('U')]
r.pivot('title', 'country', 'date')
# Out:
# country                                                UK        USA  \
# title
# Star Wars: Episode I - The Phantom Menace      1999-07-15 1999-05-19
# Star Wars: Episode II - Attack of the Clones   2002-05-16 2002-05-16
# Star Wars: Episode III - Revenge of the Sith   2005-05-19 2005-05-19
# Star Wars: Episode IX                                 NaT 2019-05-24
# Star Wars: Episode V - The Empire Strikes Back 1980-05-21 1980-06-20
# Star Wars: Episode VI - Return of the Jedi     1983-06-02 1983-05-25
# Star Wars: Episode VII - The Force Awakens     2015-12-17 2015-12-18
#
# country                                           Ukraine  \
# title
# Star Wars: Episode I - The Phantom Menace             NaT
# Star Wars: Episode II - Attack of the Clones   2002-06-08
# Star Wars: Episode III - Revenge of the Sith          NaT
# Star Wars: Episode IX                                 NaT
# Star Wars: Episode V - The Empire Strikes Back        NaT
# ...

# %%
c = cast
c = c[c.n <= 2]
c = c[c.name == 'Cary Grant']
c.head()
# Out:
#                         title  year        name   type          character    n
# 857640  An Affair to Remember  1957  Cary Grant  actor    Nickie Ferrante  1.0
# 857641   Arsenic and Old Lace  1944  Cary Grant  actor  Mortimer Brewster  1.0
# 857642         Big Brown Eyes  1936  Cary Grant  actor         Danny Barr  1.0
# 857644         Born to Be Bad  1934  Cary Grant  actor     Malcolm Trevor  2.0
# 857645       Bringing Up Baby  1938  Cary Grant  actor              David  2.0

# %%
# disregard the below - he supposedly fixed this bug

c = c.merge(cast, on=['title', 'year'])
c = c[(c.n_y <= 2)]# & (c.n <= 2)]
c = c[c.name_y != 'Cary Grant']
c
# Out:
#                       title  year      name_x type_x      character_x  n_x  \
# 80    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 81    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 82    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 83    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 84    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 85    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 86    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 87    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 88    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 89    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# 90    An Affair to Remember  1957  Cary Grant  actor  Nickie Ferrante  1.0
# ...
